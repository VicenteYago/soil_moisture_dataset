# %% [markdown]
# # Exploring Dataset_v0

# %%
import matplotlib.pyplot as plt                      
import datetime                                     
import glob                                         
import colorcet as cc                               
import xarray as xr                                  
import rioxarray                                    
import pickle                                       
import os                                            
from pathlib import Path                                                                 #
import shutil
import re
import numpy as np
import glob
import colorcet as cc                                
from matplotlib.colors import LinearSegmentedColormap
import pandas as pd

from optram import *

colors = ["red", "darkorange", "yellow", "palegreen", "springgreen", "cyan", "blue"]
custom_cmap_w = LinearSegmentedColormap.from_list("mycmap", colors)

# %% [markdown]
# ## Intro

# %% [markdown]
# Soil Moisture dataset created with OPTRAM outputs

# %% [markdown]
# The dimensional soil moisture maps (THETA) are built with the normalized soil moisture maps (W)

# %% [markdown]
# ## File structure

# %%
BASE_DIR = "./"

# %%
! du -h ./dataset_v0/
# Out:
# du: cannot access './dataset_v0/': No such file or directory

# %% [markdown]
# All bands (except SCL) have the `masked` subfolders:

# %%
BASE_DIR_R     = os.path.join(BASE_DIR,"R/masked")
BASE_DIR_G     = os.path.join(BASE_DIR,"G/masked")
BASE_DIR_B     = os.path.join(BASE_DIR,"B/masked")
BASE_DIR_NIR   = os.path.join(BASE_DIR,"NIR/masked")
BASE_DIR_NDVI  = os.path.join(BASE_DIR,"NDVI/masked")
BASE_DIR_SWIR  = os.path.join(BASE_DIR,"SWIR/masked")
BASE_DIR_W     = os.path.join(BASE_DIR,"W/masked")
BASE_DIR_THETA = os.path.join(BASE_DIR,"THETA/masked")

band_dirs = [
 BASE_DIR_R,    
 BASE_DIR_G,   
 BASE_DIR_B,
 BASE_DIR_NIR,  
 BASE_DIR_NDVI,
 BASE_DIR_SWIR ,
 BASE_DIR_W , 
 BASE_DIR_THETA
]

bands_dict = dict(zip(
    ["R","G","B","NIR","NDVI","SWIR","W","THETA"],
band_dirs))

bands_dict
# Out:
# {'R': './R/masked',
#  'G': './G/masked',
#  'B': './B/masked',
#  'NIR': './NIR/masked',
#  'NDVI': './NDVI/masked',
#  'SWIR': './SWIR/masked',
#  'W': './W/masked',
#  'THETA': './THETA/masked'}

# %% [markdown]
# ## Loading images

# %%
dir_W    = bands_dict["W"]
dir_THETA = bands_dict["THETA"]


W_files = [f for f in os.listdir(dir_W) if os.path.isfile(os.path.join(dir_W, f))]
THETA_files = [f for f in os.listdir(dir_THETA) if os.path.isfile(os.path.join(dir_THETA, f))]

W_files.sort()
THETA_files.sort()

# %%
W_files[:10]
# Out:
# ['S2A2A_20190105_041_Walnut-Gulch_W.tif',
#  'S2A2A_20190125_041_Walnut-Gulch_W.tif',
#  'S2A2A_20190204_041_Walnut-Gulch_W.tif',
#  'S2A2A_20190214_041_Walnut-Gulch_W.tif',
#  'S2A2A_20190224_041_Walnut-Gulch_W.tif',
#  'S2A2A_20190306_041_Walnut-Gulch_W.tif',
#  'S2A2A_20190316_041_Walnut-Gulch_W.tif',
#  'S2A2A_20190326_041_Walnut-Gulch_W.tif',
#  'S2A2A_20190405_041_Walnut-Gulch_W.tif',
#  'S2A2A_20190415_041_Walnut-Gulch_W.tif']

# %% [markdown]
# ## Visualize

# %%
file_idx = 10

W     = rioxarray.open_rasterio(os.path.join(dir_W, W_files[file_idx]), masked=True)
THETA = rioxarray.open_rasterio(os.path.join(dir_THETA, THETA_files[file_idx]), masked=True)

fig, axs = plt.subplots(1,2, figsize = (25,5))
W.plot(ax = axs[0], cmap = custom_cmap_w,  vmin = 0, vmax = 1)
THETA.plot(ax = axs[1], cmap = "Blues", vmin = 0, vmax = 25)
axs[0].title.set_text(W_files[file_idx])
axs[1].title.set_text(THETA_files[file_idx])


fig, axs = plt.subplots(1,2, figsize = (25,5))
W.plot.hist(ax = axs[0])
THETA.plot.hist(ax = axs[1])
axs[0].title.set_text(W_files[file_idx])
axs[1].title.set_text(THETA_files[file_idx])
plt.plot()
# Out:
# []

# %% [markdown]
# Obviously they share distribution since THETA is _only_ a des-normalization based on local sensing data.

# %% [markdown]
# ## ACCESS DATA

# %%
W.data
# Out:
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]], dtype=float32)

# %%
np.nanmean(W.data)
# Out:
# 0.18533124

# %% [markdown]
# ## SUBSET

# %%
fig, axs = plt.subplots(figsize = (15,7))
THETA.where(THETA>10).plot(cmap = "Blues")
axs.title.set_text("High Humidity locations (%)")

# %% [markdown]
# ## In Situ validation dataset

# %% [markdown]
# Inputs :
# - R
# - G
# - B
# - NDVI
# - NIR
# - SWIR
# - W
#
# Output :
#  - THETA (SM5)

# %%
with open('./validation.pkl', 'rb') as f:
    validation = pickle.load(f)
    
validation
# Out:
#                         R     G    B   NIR  SWIR      ndvi   SM5
# datetime
# 2019-01-20 18:06:49  1584  1174  755  2088  2491  0.137255  20.0
# 2019-01-25 18:06:31  1560  1172  791  1986  2293  0.120135  19.0
# 2019-01-30 18:06:09  1314   971  651  1692  1988  0.125749  19.0
# 2019-02-04 18:05:31  1670  1332  995  2066  2623  0.105996  18.0
# 2019-03-01 18:02:49  1630  1250  910  2098  2594  0.125536  24.0
# ...                   ...   ...  ...   ...   ...       ...   ...
# 2019-12-01 18:07:21  1084   785  513  1710  1786  0.136264  16.0
# 2019-12-06 18:07:29  1406  1016  679  1964  2329  0.159211  14.0
# 2019-12-16 18:07:39  1306  1021  635  1914  2215  0.148760  13.0
# 2019-12-21 18:07:41  1306   997  731  1920  2214  0.118138  13.0
# 2019-12-26 18:07:49  1220   904  623  1716  1998  0.139729  14.0
#
# [627 rows x 7 columns]
